# %%
from google.colab import drive
drive.mount("/content/drive")

import os
path="/content/drive/MyDrive/workspace/K-BERT-hate-detection"
os.chdir(path)
os.listdir(path)
# Out:
# Mounted at /content/drive
# ['outputs',
#  'requirements.txt',
#  '.gitignore',
#  'models',
#  'uer',
#  'get_kbert_repr.py',
#  'log',
#  '.idea',
#  'data',
#  '__pycache__',
#  'brain',
#  'pretrain.py',
#  'parser.py',
#  'data_utils.py',
#  'run_kbert_cls.py',
#  'colab_scripts.ipynb']

# %%
# !nvidia-smi
# Out:
# Sat Oct  8 07:07:33 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.9 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 163 kB 72.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 53.8 MB/s
# ...

# %%
# !python run_kbert_cls.py # 加入 LSTM，缩减词表 best:0.7231

# %%
# !python run_kbert_cls.py
# Out:
# Vocabulary Size:  261
# vocab size: 261 before union
# vocab size: 9212 after union
# vocab size: 9212 before union
# vocab size: 9491 after union
# vocab size: 9491 before union
# vocab size: 9721 after union
# vocab size: 9721 before union
# vocab size: 10847 after union
# Vocabulary Size:  51
# Vocabulary Size:  218
# [BertClassifier] use visible_matrix: True
# [KnowledgeGraph] Loading spo from brain/kgs/hate_brains.spo
# Start training.
# Loading sentences from data/implicit_hate_v1_stg1_posts/train.tsv
# There are 15035 sentence in total. We use 1 processes to inject knowledge into sentences.
# Progress of process 0: 0/15035
# Progress of process 0: 1000/15035
# Progress of process 0: 2000/15035
# Progress of process 0: 3000/15035
# Progress of process 0: 4000/15035
# Progress of process 0: 5000/15035
# Progress of process 0: 6000/15035
# Progress of process 0: 7000/15035
# Progress of process 0: 8000/15035
# Progress of process 0: 9000/15035
# ...
